# %%
from keras.optimizers import Adam
from keras.layers import (
    Conv2D, MaxPooling2D, Conv2DTranspose, Input, concatenate, BatchNormalization,
    Dropout, Lambda, Dense, Activation, Flatten, SpatialDropout2D, UpSampling2D,Conv3D,Conv3DTranspose,MaxPooling3D
)
from keras.metrics import MeanIoU,AUC,Precision,Recall,Accuracy
from keras.models import Model, Sequential
from keras.losses import CategoricalCrossentropy
from keras.utils import Sequence
from tensorflow.keras import regularizers
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import os
from keras.callbacks import EarlyStopping, ModelCheckpoint
import h5py
import tensorflow.keras.backend as k
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc
import tensorflow as tf
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau

# %%
kernel_initializer =  'he_uniform'

def simple_3dnestedunet_model(IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, IMG_CHANNELS, num_classes):
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, IMG_CHANNELS))
    s = inputs

    # x0_0    1st layer
    c1 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(s)
    c1 = BatchNormalization()(c1)
    c1 = Dropout(0.1)(c1)
    c1 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c1)
    c1 = BatchNormalization()(c1)
    p1 = MaxPooling3D((2, 2, 2))(c1)

    print("c1",c1.shape,"p1",p1.shape)

    #x1_0      64
    c2 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p1)
    c2 = BatchNormalization()(c2)
    c2 = Dropout(0.1)(c2)
    c2 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c2)
    c2 = BatchNormalization()(c2)
    p2 = MaxPooling3D((2, 2, 2))(c2)
    print("c2",c2.shape,"p2",p2.shape)


    # x0_1         d
    u1 = Conv3DTranspose(32, (2, 2, 2), strides=(2, 2, 2), padding='same')(c2)
    u1 = concatenate([c1,u1])
    u1 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u1)
    u1 = BatchNormalization()(u1)
    u1 = Dropout(0.2)(u1)
    u1 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u1)
    u1 = BatchNormalization()(u1)
    print("u1",u1.shape)

    #x2_0         d
    c3 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p2)
    c3 = BatchNormalization()(c3)
    c3 = Dropout(0.1)(c3)
    c3 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c3)
    c3 = BatchNormalization()(c3)
    p3 = MaxPooling3D((2, 2, 2))(c3)

    #x1_1        d
    u2 = Conv3DTranspose(64, (2, 2, 2), strides=(2, 2, 2), padding='same')(c3)
    u2 = concatenate([c2,u2])
    u2 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u2)
    u2 = BatchNormalization()(u2)
    u2 = Dropout(0.2)(u2)
    u2 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u2)
    u2 = BatchNormalization()(u2)

    #x0_2
    u3 = Conv3DTranspose(32, (2, 2, 2), strides=(2, 2, 2), padding='same')(u2)
    u3 = concatenate([c1,u1,u3])
    u3 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u3)
    u3 = BatchNormalization()(u3)
    u3 = Dropout(0.2)(u3)
    u3 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u3)
    u3 = BatchNormalization()(u3)

    #x3_0
    c4 = Conv3D(256, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p3)
    c4 = BatchNormalization()(c4)
    c4 = Dropout(0.1)(c4)
    c4 = Conv3D(256, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c4)
    c4 = BatchNormalization()(c4)
    p4 = MaxPooling3D((2, 2, 2))(c4)

    #x2_1
    u4 = Conv3DTranspose(128, (2, 2, 2), strides=(2, 2, 2), padding='same')(c4)
    u4 = concatenate([c3,u4])
    u4 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u4)
    u4 = BatchNormalization()(u4)
    u4 = Dropout(0.2)(u4)
    u4 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u4)
    u4 = BatchNormalization()(u4)

    #1_2
    u5 = Conv3DTranspose(64, (2, 2, 2), strides=(2, 2, 2), padding='same')(u4)
    u5 = concatenate([c2,u2,u5])
    u5 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u5)
    u5 = BatchNormalization()(u5)
    u5 = Dropout(0.2)(u5)
    u5 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u5)
    u5 = BatchNormalization()(u5)

    #x0_3
    u6 = Conv3DTranspose(32, (2, 2, 2), strides=(2, 2, 2), padding='same')(u5)
    u6 = concatenate([c1,u1,u3,u6])
    u6 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u6)
    u6 = BatchNormalization()(u6)
    u6 = Dropout(0.2)(u6)
    u6 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u6)
    u6 = BatchNormalization()(u6)


    #x4_0
    c5 = Conv3D(512, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(p4)
    c5 = BatchNormalization()(c5)
    c5 = Dropout(0.1)(c5)
    c5 = Conv3D(512, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(c5)
    c5 = BatchNormalization()(c5)

    #x3_1
    u7 = Conv3DTranspose(256, (2, 2, 2), strides=(2, 2, 2), padding='same')(c5)
    u7 = concatenate([c4,u7])
    u7 = Conv3D(256, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u7)
    u7 = BatchNormalization()(u7)
    u7 = Dropout(0.2)(u7)
    u7 = Conv3D(256, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u7)
    u7 = BatchNormalization()(u7)

    #x2_2
    u8 = Conv3DTranspose(128, (2, 2, 2), strides=(2, 2, 2), padding='same')(u7)
    u8 = concatenate([c3,u4,u8])
    u8 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u8)
    u8 = BatchNormalization()(u8)
    u8 = Dropout(0.2)(u8)
    u8 = Conv3D(128, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u8)
    u8 = BatchNormalization()(u8)

    #x1_3
    u9 = Conv3DTranspose(64, (2, 2, 2), strides=(2, 2, 2), padding='same')(u8)
    u9 = concatenate([c2,u2,u5,u9])
    u9 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u9)
    u9 = BatchNormalization()(u9)
    u9 = Dropout(0.2)(u9)
    u9 = Conv3D(64, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u9)
    u9 = BatchNormalization()(u9)

    #x0_4
    u10 = Conv3DTranspose(32, (2, 2, 2), strides=(2, 2, 2), padding='same')(u9)
    u10 = concatenate([c1,u1,u3,u6,u10])
    u10 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u10)
    u10 = BatchNormalization()(u10)
    u10 = Dropout(0.2)(u10)
    u10 = Conv3D(32, (3, 3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same')(u10)
    u10 = BatchNormalization()(u10)

    #final layer
    outputs = Conv3D(num_classes, (1, 1, 1), activation='softmax')(u10)
    model = Model(inputs=[inputs], outputs=[outputs])
    model.compile(optimizer=Adam(learning_rate=1e-3),
              loss=CategoricalCrossentropy(),
              metrics=[Accuracy(name="accuracy"), MeanIoU(num_classes=4,name="iou"),AUC(name="auc"),Recall(name="recall"),Precision(name="precision")])
    model.summary()

    return model

# %%
MODEL=simple_3dnestedunet_model(128,128,128,3,4)
# Out:
# c1 (None, 128, 128, 128, 32) p1 (None, 64, 64, 64, 32)
# c2 (None, 64, 64, 64, 64) p2 (None, 32, 32, 32, 64)
# u1 (None, 128, 128, 128, 32)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 128, 3)]   0         []
#
#  conv3d (Conv3D)             (None, 128, 128, 128, 32)    2624      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 128, 128, 128, 32)    128       ['conv3d[0][0]']
#  Normalization)
#
#  dropout (Dropout)           (None, 128, 128, 128, 32)    0         ['batch_normalization[0][0]']
#
#  conv3d_1 (Conv3D)           (None, 128, 128, 128, 32)    27680     ['dropout[0][0]']
#
#  batch_normalization_1 (Bat  (None, 128, 128, 128, 32)    128       ['conv3d_1[0][0]']
#  chNormalization)
#
#  max_pooling3d (MaxPooling3  (None, 64, 64, 64, 32)       0         ['batch_normalization_1[0][0]'
#  D)                                                                 ]
#
#  conv3d_2 (Conv3D)           (None, 64, 64, 64, 64)       55360     ['max_pooling3d[0][0]']
#
#  batch_normalization_2 (Bat  (None, 64, 64, 64, 64)       256       ['conv3d_2[0][0]']
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 64, 64, 64, 64)       0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv3d_3 (Conv3D)           (None, 64, 64, 64, 64)       110656    ['dropout_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 64, 64, 64, 64)       256       ['conv3d_3[0][0]']
#  chNormalization)
#
#  max_pooling3d_1 (MaxPoolin  (None, 32, 32, 32, 64)       0         ['batch_normalization_3[0][0]'
#  g3D)                                                               ]
#
#  conv3d_6 (Conv3D)           (None, 32, 32, 32, 128)      221312    ['max_pooling3d_1[0][0]']
#
#  batch_normalization_6 (Bat  (None, 32, 32, 32, 128)      512       ['conv3d_6[0][0]']
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 32, 32, 32, 128)      0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv3d_7 (Conv3D)           (None, 32, 32, 32, 128)      442496    ['dropout_3[0][0]']
#
#  batch_normalization_7 (Bat  (None, 32, 32, 32, 128)      512       ['conv3d_7[0][0]']
#  chNormalization)
#
#  max_pooling3d_2 (MaxPoolin  (None, 16, 16, 16, 128)      0         ['batch_normalization_7[0][0]'
#  g3D)                                                               ]
#
#  conv3d_12 (Conv3D)          (None, 16, 16, 16, 256)      884992    ['max_pooling3d_2[0][0]']
#
#  batch_normalization_12 (Ba  (None, 16, 16, 16, 256)      1024      ['conv3d_12[0][0]']
#  tchNormalization)
#
#  dropout_6 (Dropout)         (None, 16, 16, 16, 256)      0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv3d_13 (Conv3D)          (None, 16, 16, 16, 256)      1769728   ['dropout_6[0][0]']
#
#  batch_normalization_13 (Ba  (None, 16, 16, 16, 256)      1024      ['conv3d_13[0][0]']
#  tchNormalization)
#
#  max_pooling3d_3 (MaxPoolin  (None, 8, 8, 8, 256)         0         ['batch_normalization_13[0][0]
#  g3D)                                                               ']
#
#  conv3d_20 (Conv3D)          (None, 8, 8, 8, 512)         3539456   ['max_pooling3d_3[0][0]']
#
#  batch_normalization_20 (Ba  (None, 8, 8, 8, 512)         2048      ['conv3d_20[0][0]']
#  tchNormalization)
#
#  dropout_10 (Dropout)        (None, 8, 8, 8, 512)         0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv3d_21 (Conv3D)          (None, 8, 8, 8, 512)         7078400   ['dropout_10[0][0]']
#
#  batch_normalization_21 (Ba  (None, 8, 8, 8, 512)         2048      ['conv3d_21[0][0]']
#  tchNormalization)
#
#  conv3d_transpose_6 (Conv3D  (None, 16, 16, 16, 256)      1048832   ['batch_normalization_21[0][0]
#  Transpose)                                                         ']
#
#  conv3d_transpose_3 (Conv3D  (None, 32, 32, 32, 128)      262272    ['batch_normalization_13[0][0]
#  Transpose)                                                         ']
#
#  concatenate_6 (Concatenate  (None, 16, 16, 16, 512)      0         ['batch_normalization_13[0][0]
#  )                                                                  ',
#                                                                      'conv3d_transpose_6[0][0]']
#
#  conv3d_transpose_1 (Conv3D  (None, 64, 64, 64, 64)       65600     ['batch_normalization_7[0][0]'
#  Transpose)                                                         ]
#
#  concatenate_3 (Concatenate  (None, 32, 32, 32, 256)      0         ['batch_normalization_7[0][0]'
#  )                                                                  , 'conv3d_transpose_3[0][0]']
#
#  conv3d_22 (Conv3D)          (None, 16, 16, 16, 256)      3539200   ['concatenate_6[0][0]']
#
#  conv3d_transpose (Conv3DTr  (None, 128, 128, 128, 32)    16416     ['batch_normalization_3[0][0]'
#  anspose)                                                           ]
#
#  concatenate_1 (Concatenate  (None, 64, 64, 64, 128)      0         ['batch_normalization_3[0][0]'
#  )                                                                  , 'conv3d_transpose_1[0][0]']
#
#  conv3d_14 (Conv3D)          (None, 32, 32, 32, 128)      884864    ['concatenate_3[0][0]']
#
#  batch_normalization_22 (Ba  (None, 16, 16, 16, 256)      1024      ['conv3d_22[0][0]']
#  tchNormalization)
#
#  concatenate (Concatenate)   (None, 128, 128, 128, 64)    0         ['batch_normalization_1[0][0]'
#                                                                     , 'conv3d_transpose[0][0]']
#
#  conv3d_8 (Conv3D)           (None, 64, 64, 64, 64)       221248    ['concatenate_1[0][0]']
#
#  batch_normalization_14 (Ba  (None, 32, 32, 32, 128)      512       ['conv3d_14[0][0]']
#  tchNormalization)
#
#  dropout_11 (Dropout)        (None, 16, 16, 16, 256)      0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv3d_4 (Conv3D)           (None, 128, 128, 128, 32)    55328     ['concatenate[0][0]']
#
#  batch_normalization_8 (Bat  (None, 64, 64, 64, 64)       256       ['conv3d_8[0][0]']
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 32, 32, 32, 128)      0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv3d_23 (Conv3D)          (None, 16, 16, 16, 256)      1769728   ['dropout_11[0][0]']
#
#  batch_normalization_4 (Bat  (None, 128, 128, 128, 32)    128       ['conv3d_4[0][0]']
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 64, 64, 64, 64)       0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv3d_15 (Conv3D)          (None, 32, 32, 32, 128)      442496    ['dropout_7[0][0]']
#
#  batch_normalization_23 (Ba  (None, 16, 16, 16, 256)      1024      ['conv3d_23[0][0]']
#  tchNormalization)
#
#  dropout_2 (Dropout)         (None, 128, 128, 128, 32)    0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv3d_9 (Conv3D)           (None, 64, 64, 64, 64)       110656    ['dropout_4[0][0]']
#
#  batch_normalization_15 (Ba  (None, 32, 32, 32, 128)      512       ['conv3d_15[0][0]']
#  tchNormalization)
#
#  conv3d_transpose_7 (Conv3D  (None, 32, 32, 32, 128)      262272    ['batch_normalization_23[0][0]
#  Transpose)                                                         ']
#
#  conv3d_5 (Conv3D)           (None, 128, 128, 128, 32)    27680     ['dropout_2[0][0]']
#
#  batch_normalization_9 (Bat  (None, 64, 64, 64, 64)       256       ['conv3d_9[0][0]']
#  chNormalization)
#
#  conv3d_transpose_4 (Conv3D  (None, 64, 64, 64, 64)       65600     ['batch_normalization_15[0][0]
#  Transpose)                                                         ']
#
#  concatenate_7 (Concatenate  (None, 32, 32, 32, 384)      0         ['batch_normalization_7[0][0]'
#  )                                                                  , 'batch_normalization_15[0][0
#                                                                     ]',
#                                                                      'conv3d_transpose_7[0][0]']
#
#  batch_normalization_5 (Bat  (None, 128, 128, 128, 32)    128       ['conv3d_5[0][0]']
#  chNormalization)
#
#  conv3d_transpose_2 (Conv3D  (None, 128, 128, 128, 32)    16416     ['batch_normalization_9[0][0]'
#  Transpose)                                                         ]
#
#  concatenate_4 (Concatenate  (None, 64, 64, 64, 192)      0         ['batch_normalization_3[0][0]'
#  )                                                                  , 'batch_normalization_9[0][0]
#                                                                     ',
#                                                                      'conv3d_transpose_4[0][0]']
#
#  conv3d_24 (Conv3D)          (None, 32, 32, 32, 128)      1327232   ['concatenate_7[0][0]']
#
#  concatenate_2 (Concatenate  (None, 128, 128, 128, 96)    0         ['batch_normalization_1[0][0]'
#  )                                                                  , 'batch_normalization_5[0][0]
#                                                                     ',
#                                                                      'conv3d_transpose_2[0][0]']
#
#  conv3d_16 (Conv3D)          (None, 64, 64, 64, 64)       331840    ['concatenate_4[0][0]']
#
#  batch_normalization_24 (Ba  (None, 32, 32, 32, 128)      512       ['conv3d_24[0][0]']
#  tchNormalization)
#
#  conv3d_10 (Conv3D)          (None, 128, 128, 128, 32)    82976     ['concatenate_2[0][0]']
#
#  batch_normalization_16 (Ba  (None, 64, 64, 64, 64)       256       ['conv3d_16[0][0]']
#  tchNormalization)
#
#  dropout_12 (Dropout)        (None, 32, 32, 32, 128)      0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  batch_normalization_10 (Ba  (None, 128, 128, 128, 32)    128       ['conv3d_10[0][0]']
#  tchNormalization)
#
#  dropout_8 (Dropout)         (None, 64, 64, 64, 64)       0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv3d_25 (Conv3D)          (None, 32, 32, 32, 128)      442496    ['dropout_12[0][0]']
#
#  dropout_5 (Dropout)         (None, 128, 128, 128, 32)    0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv3d_17 (Conv3D)          (None, 64, 64, 64, 64)       110656    ['dropout_8[0][0]']
#
#  batch_normalization_25 (Ba  (None, 32, 32, 32, 128)      512       ['conv3d_25[0][0]']
#  tchNormalization)
#
#  conv3d_11 (Conv3D)          (None, 128, 128, 128, 32)    27680     ['dropout_5[0][0]']
#
#  batch_normalization_17 (Ba  (None, 64, 64, 64, 64)       256       ['conv3d_17[0][0]']
#  tchNormalization)
#
#  conv3d_transpose_8 (Conv3D  (None, 64, 64, 64, 64)       65600     ['batch_normalization_25[0][0]
#  Transpose)                                                         ']
#
#  batch_normalization_11 (Ba  (None, 128, 128, 128, 32)    128       ['conv3d_11[0][0]']
#  tchNormalization)
#
#  conv3d_transpose_5 (Conv3D  (None, 128, 128, 128, 32)    16416     ['batch_normalization_17[0][0]
#  Transpose)                                                         ']
#
#  concatenate_8 (Concatenate  (None, 64, 64, 64, 256)      0         ['batch_normalization_3[0][0]'
#  )                                                                  , 'batch_normalization_9[0][0]
#                                                                     ',
#                                                                      'batch_normalization_17[0][0]
#                                                                     ',
#                                                                      'conv3d_transpose_8[0][0]']
#
#  concatenate_5 (Concatenate  (None, 128, 128, 128, 128)   0         ['batch_normalization_1[0][0]'
#  )                                                                  , 'batch_normalization_5[0][0]
#                                                                     ',
#                                                                      'batch_normalization_11[0][0]
#                                                                     ',
#                                                                      'conv3d_transpose_5[0][0]']
#
#  conv3d_26 (Conv3D)          (None, 64, 64, 64, 64)       442432    ['concatenate_8[0][0]']
#
#  conv3d_18 (Conv3D)          (None, 128, 128, 128, 32)    110624    ['concatenate_5[0][0]']
#
#  batch_normalization_26 (Ba  (None, 64, 64, 64, 64)       256       ['conv3d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 128, 128, 128, 32)    128       ['conv3d_18[0][0]']
#  tchNormalization)
#
#  dropout_13 (Dropout)        (None, 64, 64, 64, 64)       0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  dropout_9 (Dropout)         (None, 128, 128, 128, 32)    0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv3d_27 (Conv3D)          (None, 64, 64, 64, 64)       110656    ['dropout_13[0][0]']
#
#  conv3d_19 (Conv3D)          (None, 128, 128, 128, 32)    27680     ['dropout_9[0][0]']
#
#  batch_normalization_27 (Ba  (None, 64, 64, 64, 64)       256       ['conv3d_27[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 128, 128, 128, 32)    128       ['conv3d_19[0][0]']
#  tchNormalization)
#
#  conv3d_transpose_9 (Conv3D  (None, 128, 128, 128, 32)    16416     ['batch_normalization_27[0][0]
#  Transpose)                                                         ']
#
#  concatenate_9 (Concatenate  (None, 128, 128, 128, 160)   0         ['batch_normalization_1[0][0]'
#  )                                                                  , 'batch_normalization_5[0][0]
#                                                                     ',
#                                                                      'batch_normalization_11[0][0]
#                                                                     ',
#                                                                      'batch_normalization_19[0][0]
#                                                                     ',
#                                                                      'conv3d_transpose_9[0][0]']
#
#  conv3d_28 (Conv3D)          (None, 128, 128, 128, 32)    138272    ['concatenate_9[0][0]']
#
#  batch_normalization_28 (Ba  (None, 128, 128, 128, 32)    128       ['conv3d_28[0][0]']
#  tchNormalization)
#
#  dropout_14 (Dropout)        (None, 128, 128, 128, 32)    0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv3d_29 (Conv3D)          (None, 128, 128, 128, 32)    27680     ['dropout_14[0][0]']
#
#  batch_normalization_29 (Ba  (None, 128, 128, 128, 32)    128       ['conv3d_29[0][0]']
#  tchNormalization)
#
#  conv3d_30 (Conv3D)          (None, 128, 128, 128, 4)     132       ['batch_normalization_29[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 26214692 (100.00 MB)
# Trainable params: 26207396 (99.97 MB)
# Non-trainable params: 7296 (28.50 KB)
# __________________________________________________________________________________________________
